# %%
# Dependencies
import numpy as np
import tweepy
import time
import json

# Twitter API Keys
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Target Term
# target_term = "@DaDataBootCamp"
target_term = "@katyperry"

# Opening message
print("We're going live, sir!")

# Search for most recent tweet directed to the account
public_tweets = api.search(target_term, count=1, result_type="recent")

# Extract all hashtags from tweets directed to the account
for tweet in public_tweets["statuses"]:

    # Print tweet in JSON
    print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))

    # Print tweet text
    print(tweet["text"])

    # Loop through all hashtags and print each one included
    for hashtag in tweet["entities"]["hashtags"]:
        print(hashtag["text"])
# Out:
# We're going live, sir!
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 17 17:31:32 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/AJkzXgWp49",
#                 "expanded_url": "https://twitter.com/KatyCute_/status/974704398097141760/video/1",
#                 "id": 974703721937588225,
#                 "id_str": "974703721937588225",
#                 "indices": [
#                     82,
#                     105
#                 ],
#                 "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                 "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "medium": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "small": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 974704398097141760,
#                 "source_status_id_str": "974704398097141760",
#                 "source_user_id": 2750005570,
#                 "source_user_id_str": "2750005570",
#                 "type": "photo",
#                 "url": "https://t.co/AJkzXgWp49"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2750005570,
#                 "id_str": "2750005570",
#                 "indices": [
#                     3,
#                     13
#                 ],
#                 "name": "Solci",
#                 "screen_name": "KatyCute_"
#             },
#             {
#                 "id": 21447363,
#                 "id_str": "21447363",
#                 "indices": [
#                     68,
#                     78
#                 ],
#                 "name": "KATY PERRY",
#                 "screen_name": "katyperry"
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "additional_media_info": {
#                     "monetizable": false,
#                     "source_user": {
#                         "contributors_enabled": false,
#                         "created_at": "Fri Aug 22 04:33:11 +0000 2014",
#                         "default_profile": false,
#                         "default_profile_image": false,
#                         "description": "Be yourself and you can be anything\u2728               {27/09/11 CDT} {03/10/15 PWT} {11/03/18 WTT}",
#                         "entities": {
#                             "description": {
#                                 "urls": []
#                             }
#                         },
#                         "favourites_count": 786,
#                         "follow_request_sent": false,
#                         "followers_count": 3835,
#                         "following": false,
#                         "friends_count": 286,
#                         "geo_enabled": true,
#                         "has_extended_profile": true,
#                         "id": 2750005570,
#                         "id_str": "2750005570",
#                         "is_translation_enabled": false,
#                         "is_translator": false,
#                         "lang": "es",
#                         "listed_count": 22,
#                         "location": "Argentina\ud83c\udde6\ud83c\uddf7",
#                         "name": "Solci",
#                         "notifications": false,
#                         "profile_background_color": "000000",
#                         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/627941907210072064/9qVCgSM_.jpg",
#                         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/627941907210072064/9qVCgSM_.jpg",
#                         "profile_background_tile": false,
#                         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2750005570/1518222523",
#                         "profile_image_url": "http://pbs.twimg.com/profile_images/974466952293965825/opgbKMbv_normal.jpg",
#                         "profile_image_url_https": "https://pbs.twimg.com/profile_images/974466952293965825/opgbKMbv_normal.jpg",
#                         "profile_link_color": "000000",
#                         "profile_sidebar_border_color": "000000",
#                         "profile_sidebar_fill_color": "000000",
#                         "profile_text_color": "000000",
#                         "profile_use_background_image": true,
#                         "protected": false,
#                         "screen_name": "KatyCute_",
#                         "statuses_count": 16571,
#                         "time_zone": "Buenos Aires",
#                         "translator_type": "none",
#                         "url": null,
#                         "utc_offset": -10800,
#                         "verified": false
#                     }
#                 },
#                 "display_url": "pic.twitter.com/AJkzXgWp49",
#                 "expanded_url": "https://twitter.com/KatyCute_/status/974704398097141760/video/1",
#                 "id": 974703721937588225,
#                 "id_str": "974703721937588225",
#                 "indices": [
#                     82,
#                     105
#                 ],
#                 "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                 "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "medium": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "small": {
#                         "h": 640,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "source_status_id": 974704398097141760,
#                 "source_status_id_str": "974704398097141760",
#                 "source_user_id": 2750005570,
#                 "source_user_id_str": "2750005570",
#                 "type": "video",
#                 "url": "https://t.co/AJkzXgWp49",
#                 "video_info": {
#                     "aspect_ratio": [
#                         1,
#                         1
#                     ],
#                     "duration_millis": 13667,
#                     "variants": [
#                         {
#                             "bitrate": 256000,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/vid/240x240/1iL2grqiysDqdwKd.mp4"
#                         },
#                         {
#                             "bitrate": 832000,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/vid/480x480/TOJxTUl10Go5QMDQ.mp4"
#                         },
#                         {
#                             "content_type": "application/x-mpegURL",
#                             "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/pl/FCOEwXfVYw1fUMmh.m3u8"
#                         }
#                     ]
#                 }
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 975062088602259456,
#     "id_str": "975062088602259456",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 47,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Mar 16 17:50:12 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/AJkzXgWp49",
#                     "expanded_url": "https://twitter.com/KatyCute_/status/974704398097141760/video/1",
#                     "id": 974703721937588225,
#                     "id_str": "974703721937588225",
#                     "indices": [
#                         67,
#                         90
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "medium": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "small": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/AJkzXgWp49"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 21447363,
#                     "id_str": "21447363",
#                     "indices": [
#                         53,
#                         63
#                     ],
#                     "name": "KATY PERRY",
#                     "screen_name": "katyperry"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "additional_media_info": {
#                         "monetizable": false
#                     },
#                     "display_url": "pic.twitter.com/AJkzXgWp49",
#                     "expanded_url": "https://twitter.com/KatyCute_/status/974704398097141760/video/1",
#                     "id": 974703721937588225,
#                     "id_str": "974703721937588225",
#                     "indices": [
#                         67,
#                         90
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/974703721937588225/pu/img/_JI6l4MuSTqnz3vy.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "medium": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "small": {
#                             "h": 640,
#                             "resize": "fit",
#                             "w": 640
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "video",
#                     "url": "https://t.co/AJkzXgWp49",
#                     "video_info": {
#                         "aspect_ratio": [
#                             1,
#                             1
#                         ],
#                         "duration_millis": 13667,
#                         "variants": [
#                             {
#                                 "bitrate": 256000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/vid/240x240/1iL2grqiysDqdwKd.mp4"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/vid/480x480/TOJxTUl10Go5QMDQ.mp4"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/974703721937588225/pu/pl/FCOEwXfVYw1fUMmh.m3u8"
#                             }
#                         ]
#                     }
#                 }
#             ]
#         },
#         "favorite_count": 143,
#         "favorited": false,
#         "geo": null,
#         "id": 974704398097141760,
#         "id_str": "974704398097141760",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 47,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "text": "\"How do you say? Les mucho? I mean les amo?\" LOS AMO @katyperry\ud83c\udde6\ud83c\uddf7\u2764 https://t.co/AJkzXgWp49",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Fri Aug 22 04:33:11 +0000 2014",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "Be yourself and you can be anything\u2728               {27/09/11 CDT} {03/10/15 PWT} {11/03/18 WTT}",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "favourites_count": 786,
#             "follow_request_sent": false,
#             "followers_count": 3835,
#             "following": false,
#             "friends_count": 286,
#             "geo_enabled": true,
#             "has_extended_profile": true,
#             "id": 2750005570,
#             "id_str": "2750005570",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "es",
#             "listed_count": 22,
#             "location": "Argentina\ud83c\udde6\ud83c\uddf7",
#             "name": "Solci",
#             "notifications": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/627941907210072064/9qVCgSM_.jpg",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/627941907210072064/9qVCgSM_.jpg",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2750005570/1518222523",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/974466952293965825/opgbKMbv_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/974466952293965825/opgbKMbv_normal.jpg",
#             "profile_link_color": "000000",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "KatyCute_",
#             "statuses_count": 16571,
#             "time_zone": "Buenos Aires",
#             "translator_type": "none",
#             "url": null,
#             "utc_offset": -10800,
#             "verified": false
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @KatyCute_: \"How do you say? Les mucho? I mean les amo?\" LOS AMO @katyperry\ud83c\udde6\ud83c\uddf7\u2764 https://t.co/AJkzXgWp49",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Nov 28 21:18:41 +0000 2010",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "dark and twisty",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "instagram.com/agustina.g.esc\u2026",
#                         "expanded_url": "http://www.instagram.com/agustina.g.escobar",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/Bmq3YMez89"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 9479,
#         "follow_request_sent": false,
#         "followers_count": 653,
#         "following": false,
#         "friends_count": 124,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 220795525,
#         "id_str": "220795525",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 7,
#         "location": "Cloud 9",
#         "name": "amelia shepherd",
#         "notifications": false,
#         "profile_background_color": "F00966",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/834118095/1b044f83f72192029c3077c3ba68e9ab.jpeg",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/834118095/1b044f83f72192029c3077c3ba68e9ab.jpeg",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/220795525/1490485982",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/953828050751442944/qjAMJv0Z_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/953828050751442944/qjAMJv0Z_normal.jpg",
#         "profile_link_color": "F20972",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "19E0D9",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "agusperry",
#         "statuses_count": 58477,
#         "time_zone": "Buenos Aires",
#         "translator_type": "none",
#         "url": "https://t.co/Bmq3YMez89",
#         "utc_offset": -10800,
#         "verified": false
#     }
# }
# RT @KatyCute_: "How do you say? Les mucho? I mean les amo?" LOS AMO @katyperry🇦🇷❤ https://t.co/AJkzXgWp49
